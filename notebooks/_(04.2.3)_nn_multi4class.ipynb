# %% [markdown]
# # _4.2.3. (multi-class) classification using NN_
#
# Main topics of the current notebook is to focus on applying Neural Network to the problem of anomaly detection, i.e., categorizing anomalies into distinct classes : reorder, duplicate, corrupt anomaly or simply normal case.
#
# #### _a. Load Data_
#
# Recall, the dataset was already cleaned and normalized _(using StandardScaler)_. Columns with zero or near-zero variance deleted.

# %%
from xgboost import XGBClassifier

import seaborn as sns 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import os
import torch
import time 

from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import RandomizedSearchCV, train_test_split

from scipy.stats import uniform, randint

from skopt import BayesSearchCV

# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

# %%
scaled_new_dataset = "data/scaled_new_godash_dataset.csv"
scaled_new_df = pd.read_csv(scaled_new_dataset, index_col=0)

scaled_new_df.head(5)
# Out:
#      Seg_id  Arr_time  Del_Time  Stall_Dur  Rep_Level  Del_Rate  Act_Rate  \
# 0 -1.697807 -0.445033 -0.204334  -0.164204  -1.294465 -1.160341 -1.160370
# 1 -1.640070 -0.441006 -0.198458  -0.164204  -1.294465 -0.396335 -1.008632
# 2 -1.582333 -0.436192 -0.186196  -0.164204  -1.108483  0.193475 -0.664977
# 3 -1.524596 -0.430804 -0.169590  -0.164204  -0.826439  0.384235 -0.245217
# 4 -1.466860 -0.425614 -0.169846  -0.164204  -0.422082  0.397624 -0.242853
#
#    Byte_Size  Buff_Level     Width  ...        Yu      algo  nb_nodes  \
# 0  -1.160361   -0.833377 -1.247338  ...  0.360347 -1.462647  0.524565
# 1  -1.008502   -0.575036 -1.247338  ...  0.360347 -1.462647  0.524565
# 2  -0.665158   -0.460461 -0.978685  ...  0.367256 -1.462647  0.524565
# 3  -0.244990   -0.363067 -0.799582  ...  0.378520 -1.462647  0.524565
# 4  -0.242699   -0.259859 -0.665255  ...  0.394329 -1.462647  0.524565
#
#         mos       MOS  mos_label  anomaly     level   tag2  tag
# 0 -1.043858 -0.045817        bad        0 -1.083746  False    0
# 1 -1.114816 -0.045817        bad        0 -1.083746  False    0
# 2 -0.964049 -0.045817        bad        0 -1.083746  False    0
# 3 -0.956997 -0.045817        bad        0 -1.083746  False    0
# 4 -0.943719 -0.045817        bad        0 -1.083746  False    0
#
# [5 rows x 27 columns]

# %%
# Recall, all the following have been deleted --> ['Seg_Dur', 'Codec', 'FPS', 'Protocol']
all_features = ['Seg_id', 'Arr_time', 'Del_Time', 'Stall_Dur', 'Rep_Level', 'Del_Rate',
                'Act_Rate', 'Byte_Size', 'Buff_Level', 'Width',
                'Height', 'Play_Pos', 'RTT', 'P.1203', 'Clae',
                'Duanmu', 'Yin', 'Yu', 'algo', 'nb_nodes', 'mos', 'MOS', 'mos_label', 
                'anomaly', 'level', 'tag2', 'tag']

new_df = scaled_new_df [all_features]
selected_features = all_features[:-4]
target = "anomaly"

# %%
dataset_name = 'new_godash_dataset'
train = new_df.copy()
n_total = len(train)
print ("n_total = ", n_total)
print ("nb features =", len(train.columns))
print ("nan values =", train.isna().sum().sum())
# Out:
# n_total =  85596
# nb features = 27
# nan values = 0

# %% [markdown]
# #### _b. Label Encode target y_
#
# The basic Idea here is to see the problem as a binary classification problem.
#
# The population is already devided into different anomalies tag using "anomaly" column.

# %%
# {'normal': 0, 'reorder': 1, 'duplicate': 2, 'corrupt': 3}
train[target].value_counts(normalize=True)
# Out:
# 0    0.253049
# 1    0.252348
# 2    0.252348
# 3    0.242254
# Name: anomaly, dtype: float64

# %% [markdown]
# #### _c. Split_

# %%
train_val_indices, test_indices = train_test_split(range(n_total), test_size=0.2, random_state=0)
train_indices, valid_indices =    train_test_split(train_val_indices, test_size=0.2 / 0.6, random_state=0)

# This is a generic pipeline but actually no categorical features are available for this dataset
unused_feat = ["mos_label", 'tag', 'level', 'anomaly']
features = [ col for col in selected_features if col not in unused_feat+[target]] 

print ("len(features) =", len(features))

if os.getenv("CI", False):
# Take only a subsample to run CI
    X_train = train[features].values[train_indices][:1000,:]
    y_train = train[target].values[train_indices][:1000]
else:
    X_train = train[features].values[train_indices]
    y_train = train[target].values[train_indices]

X_valid = train[features].values[valid_indices]
y_valid = train[target].values[valid_indices]

X_test = train[features].values[test_indices]
y_test = train[target].values[test_indices]

print ("shape(X_train) :", X_train.shape)
print ("shape(y_train) :", y_train.shape)
# Out:
# len(features) = 22
# shape(X_train) : (45650, 22)
# shape(y_train) : (45650,)

# %% [markdown]
# #### _d. Check CUDA support_

# %%
print ("Is CUDA available :", torch.cuda.is_available())
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print ("Device :", DEVICE)
# Out:
# Is CUDA available : True
# Device : cuda

# %% [markdown]
# ### _e. (binary) classification using NN_
#
# A neural network is a computational model inspired by the structure and functioning of the human brain. A Neural network is _**trained**_ using data, adjusting the weights based on the difference between predicted and actual outcomes. This process, known as _**backpropagation**_, enables the network to _**learn complex patterns**_ and _**relationships**_ within the data.
#
# In our case, a neural network is trained to categorize instances into four classes, each representing an anomaly or normal behavior.
#
#
# <br>
#
# <div style="float: center;"><img  src="docs\pics\multi4class_nn.png"  alt="multi-class"  width="450"/>
# </div>
#
# </br>
#
# We use **_TensorFlow_**, the free and open-source library, used across a range of tasks but particularly focusing on training and inference of deep neural networks _[[wikipedia]](https://en.wikipedia.org/wiki/TensorFlow)_

# %%
# os.environ["CUDA_VISIBLE_DEVICES"]=""
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# %%
print(tf.__version__)

print('1: ', tf.config.list_physical_devices('GPU'))
print('2: ', tf.test.is_built_with_cuda)
print('3: ', tf.test.gpu_device_name())
print('4: ', tf.config.get_visible_devices())
# Out:
# 2.3.0
# 1:  []
# 2:  <function is_built_with_cuda at 0x0000013A68D60168>
# 3:
# 4:  [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
# Again, Check if TensorFlow is using GPU
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# _**a. Case without dropout layers**_
#
# Here in we will try a simple architecture with no _**dropout**_ layer and lighter _**(32x16)**_ architecture.

# %%
start_time = time.time()

# Define your model
model = models.Sequential()

# Add the input layer and the first hidden layer
model.add(layers.Dense(16, activation='relu', input_shape=(22,)))
# Add more hidden layers if needed
model.add(layers.Dense(8, activation='relu'))

# Output layer with softmax activation for multiclass classification
model.add(layers.Dense(4, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',  # Use categorical_crossentropy if your labels are one-hot encoded
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                368
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 36
# =================================================================
# Total params: 540
# Trainable params: 540
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model and store the history
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_valid, y_valid))

print(f"Training completed in +{(time.time()-start_time)//60:.2f} min.")
# Out:
# Epoch 1/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0
100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3585 - accuracy: 0.8677 - val_loss: 0.3560 - val_accuracy: 0.8696
# Epoch 64/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.3581 - accuracy: 0.8679 - val_loss: 0.3639 - val_accuracy: 0.8668
# Epoch 65/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3568 - accuracy: 0.8674 - val_loss: 0.3537 - val_accuracy: 0.8682
# Epoch 66/100
# 1427/1427 [==============================] - 4s 2ms/step - loss: 0.3567 - accuracy: 0.8679 - val_loss: 0.3531 - val_accuracy: 0.8710
# Epoch 67/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3549 - accuracy: 0.8686 - val_loss: 0.3564 - val_accuracy: 0.8683
# Epoch 68/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3551 - accuracy: 0.8685 - val_loss: 0.3536 - val_accuracy: 0.8708
# Epoch 69/100
# 1427/1427 [==============================] - 4s 2ms/step - loss: 0.3556 - accuracy: 0.8674 - val_loss: 0.3587 - val_accuracy: 0.8696
# Epoch 70/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.3538 - accuracy: 0.8690 - val_loss: 0.3500 - val_accuracy: 0.8737
# Epoch 71/100
# 1427/1427 [==============================] - 4s 2ms/step - loss: 0.3532 - accuracy: 0.8691 - val_loss: 0.3665 - val_accuracy: 0.8631
# Epoch 72/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3534 - accuracy: 0.8700 - val_loss: 0.3569 - val_accuracy: 0.8677
# Epoch 73/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3515 - accuracy: 0.8714 - val_loss: 0.3572 - val_accuracy: 0.8674
# Epoch 74/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3511 - accuracy: 0.8711 - val_loss: 0.3570 - val_accuracy: 0.8737
# Epoch 75/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3506 - accuracy: 0.8714 - val_loss: 0.3621 - val_accuracy: 0.8661
# Epoch 76/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3503 - accuracy: 0.8711 - val_loss: 0.3466 - val_accuracy: 0.8743
# Epoch 77/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3477 - accuracy: 0.8717 - val_loss: 0.3587 - val_accuracy: 0.8671
# Epoch 78/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3477 - accuracy: 0.8724 - val_loss: 0.3471 - val_accuracy: 0.8727
# Epoch 79/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3469 - accuracy: 0.8733 - val_loss: 0.3492 - val_accuracy: 0.8726
# Epoch 80/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3471 - accuracy: 0.8717 - val_loss: 0.3443 - val_accuracy: 0.8769
# Epoch 81/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3468 - accuracy: 0.8741 - val_loss: 0.3601 - val_accuracy: 0.8691
# Epoch 82/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3460 - accuracy: 0.8729 - val_loss: 0.3605 - val_accuracy: 0.8677
# Epoch 83/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3454 - accuracy: 0.8738 - val_loss: 0.3410 - val_accuracy: 0.8752
# Epoch 84/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3447 - accuracy: 0.8748 - val_loss: 0.3400 - val_accuracy: 0.8784
# Epoch 85/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3437 - accuracy: 0.8747 - val_loss: 0.3406 - val_accuracy: 0.8758
# Epoch 86/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3416 - accuracy: 0.8765 - val_loss: 0.3460 - val_accuracy: 0.8762
# Epoch 87/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.3432 - accuracy: 0.8753 - val_loss: 0.3422 - val_accuracy: 0.8754
# Epoch 88/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3404 - accuracy: 0.8760 - val_loss: 0.3482 - val_accuracy: 0.8732
# Epoch 89/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3396 - accuracy: 0.8776 - val_loss: 0.3392 - val_accuracy: 0.8791
# Epoch 90/100
# 1427/1427 [==============================] - 4s 2ms/step - loss: 0.3392 - accuracy: 0.8769 - val_loss: 0.3424 - val_accuracy: 0.8774
# Epoch 91/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3378 - accuracy: 0.8773 - val_loss: 0.3350 - val_accuracy: 0.8772
# Epoch 92/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3380 - accuracy: 0.8779 - val_loss: 0.3433 - val_accuracy: 0.8774
# Epoch 93/100
# 1427/1427 [==============================] - 4s 2ms/step - loss: 0.3356 - accuracy: 0.8776 - val_loss: 0.3376 - val_accuracy: 0.8765
# Epoch 94/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3353 - accuracy: 0.8789 - val_loss: 0.3323 - val_accuracy: 0.8814
# Epoch 95/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3353 - accuracy: 0.8781 - val_loss: 0.3396 - val_accuracy: 0.8773
# Epoch 96/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3353 - accuracy: 0.8782 - val_loss: 0.3361 - val_accuracy: 0.8780
# Epoch 97/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3332 - accuracy: 0.8798 - val_loss: 0.3296 - val_accuracy: 0.8825
# Epoch 98/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3331 - accuracy: 0.8785 - val_loss: 0.3325 - val_accuracy: 0.8798
# Epoch 99/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3311 - accuracy: 0.8804 - val_loss: 0.3307 - val_accuracy: 0.8827
# Epoch 100/100
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.3301 - accuracy: 0.8805 - val_loss: 0.3365 - val_accuracy: 0.8768
# Training completed in +5.00 min.

# %%
results = model.evaluate(X_test, y_test)
dict(zip(model.metrics_names, results))
# Out:
# 535/535 [==============================] - 1s 2ms/step - loss: 0.3309 - accuracy: 0.8801
# {'loss': 0.33089014887809753, 'accuracy': 0.8800817728042603}

# %%
# Extract training and validation loss from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot the training and validation loss
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, c="blue", label='Training loss')
plt.plot(epochs, val_loss, c="red", label='Validation loss')
plt.title('(light NN) Training and Validation Loss\n(Multi-class Anomaly Detection)\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# y_pred has shape (9473, 4)
y_vect_pred = model.predict(X_valid)

y_pred = np.argmax(y_vect_pred, axis=1)

# Create a confusion matrix
conf_matrix = confusion_matrix(y_valid, y_pred)


# Display a classification report
print("\n(light NN) Classification Report (Multi-class anomaly detection):\n")
print(classification_report(y_valid, y_pred))
# Out:
# (light NN) Classification Report (Multi-class anomaly detection):
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      5831
#            1       0.87      0.90      0.89      5718
#            2       0.81      0.88      0.84      5790
#            3       0.93      0.81      0.87      5487
#
#     accuracy                           0.88     22826
#    macro avg       0.88      0.88      0.88     22826
# weighted avg       0.88      0.88      0.88     22826

# %%
labaled_classes = ['normal','reorder', 'duplicate','corrupt']
classes = np.unique(y_train) 

classes = [classe+0.5 for classe in classes]

# Create a heatmap for the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.xticks(classes, labaled_classes, rotation=30)
plt.yticks(classes, labaled_classes, rotation=30)
plt.xlabel("<-------------------    Predicted Labels  ------------------->", fontsize=12, color="red", labelpad=18)
plt.ylabel("<-------------------    True Labels  ------------------->",  fontsize=12, color="red", labelpad=18)

plt.title("\n(light NN) Confusion Matrix \n (Multi-class Anomaly Detection)\n")
plt.tight_layout()
plt.show()

# %% [markdown]
# _**b. Case of more complex Architecture**_
#
# Next, we will try more complex architecture with two dropout layers, l2 regularization and a more complex _**(64x32)**_ architecture.

# %%
start_time = time.time()

# Define your model
complex_model = models.Sequential()

# Add the input layer and the first hidden layer
complex_model.add(layers.Dense(64, activation='relu', input_shape=(22,), kernel_regularizer=regularizers.l2(0.01)))
complex_model.add(layers.Dropout(0.5))
# Add more hidden layers if needed
complex_model.add(layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
complex_model.add(layers.Dropout(0.5))

# Output layer with softmax activation for multiclass classification
complex_model.add(layers.Dense(4, activation='softmax'))

# Compile the model
complex_model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',  # Use categorical_crossentropy if your labels are one-hot encoded
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10)

complex_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 64)                1472
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 3,684
# Trainable params: 3,684
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model and store the history
history = complex_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_valid, y_valid))

print(f"Training completed in +{(time.time()-start_time)//60:.2f} min.")
# Out:
# Epoch 1/100
# 1427/1427 [==============================] - 6s 4ms/step - loss: 1.2384 - accuracy: 0.5543 - val_loss: 0.8920 - val_accuracy: 0.7061
# Epoch 2/100
# 1427/1427 [==============================] - 5s 3ms/step - loss: 0.9281 - accuracy: 0.6571 - val_loss: 0.8261 - val_accuracy: 0.7319
# Epoch 3/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.8875 - accuracy: 0.6775 - val_loss: 0.7904 - val_accuracy: 0.7448
# Epoch 4/100
# 1427/1427 [==============================] - 5s 3ms/step - loss: 0.8664 - accuracy: 0.6881 - val_loss: 0.7729 - val_accuracy: 0.7460
# Epoch 5/100
# 1427/1427 [==============================] - 5s 3ms/step - loss: 0.8547 - accuracy: 0.6939 - val_loss: 0.7586 - val_accuracy: 0.7520
# Epoch 6/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.8410 - accuracy: 0.6981 - val_loss: 0.7463 - val_accuracy: 0.7592
# Epoch 7/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.8307 - accuracy: 0.7047 - val_loss: 0.7264 - val_accuracy: 0.7620
# Epoch 8/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.8223 - accuracy: 0.7092 - val_loss: 0.7318 - val_accuracy: 0.7505
# Epoch 9/100
# 1427/1427 [==============================] - 6s 4ms/step - loss: 0.8135 - accuracy: 0.7117 - val_loss: 0.7187 - val_accuracy: 0.7682accu
# Epoch 10/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.8092 - accuracy: 0.7145 - val_loss: 0.7117 - val_accuracy: 0.7597
# Epoch 11/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.8041 - accuracy: 0.7161 - val_loss: 0.7125 - val_accuracy: 0.7549
# Epoch 12/100
# 1427/1427 [==============================] - 5s 3ms/step - loss: 0.8004 - accuracy: 0.7195 - val_loss: 0.6955 - val_accuracy: 0.7747
# Epoch 13/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.7979 - accuracy: 0.7189 - val_loss: 0.6963 - val_accuracy: 0.7727
# Epoch 14/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.7940 - accuracy: 0.7234 - val_loss: 0.7041 - val_accuracy: 0.7570
# Epoch 15/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.7945 - accuracy: 0.7221 - val_loss: 0.7004 - val_accuracy: 0.7656
# Epoch 16/100
# 1427/1427 [==============================] - 6s 4ms/step - loss: 0.7879 - accuracy: 0.7227 - val_loss: 0.6970 - val_accuracy: 0.7608
# Epoch 17/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.7842 - accuracy: 0.7240 - val_loss: 0.6845 - val_accuracy: 0.7748
# Epoch 18/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.7865 - accuracy: 0.7227 - val_loss: 0.6898 - val_accuracy: 0.7744
# Epoch 19/100
# 1427/1427 [==============================] - 6s 4ms/step - loss: 0.7840 - accuracy: 0.7232 - val_loss: 0.6962 - val_accuracy: 0.7589s: 0.7846 - accu
# Epoch 20/100
# 1427/1427 [==============================] - 5s 4ms/step - loss: 0.7822 - accuracy: 0.7276 - val_loss: 0.6819 - val_accuracy: 0.7651
# Epoch 21/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7780 - accuracy: 0.7276 - val_loss: 0.6832 - val_accuracy: 0.7643
# Epoch 22/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7798 - accuracy: 0.7271 - val_loss: 0.6845 - val_accuracy: 0.7658
# Epoch 23/100
# 1427/1427 [==============================] - 4s 2ms/step - loss: 0.7774 - accuracy: 0.7265 - val_loss: 0.6687 - val_accuracy: 0.7802
# Epoch 24/100
# 1427/1427 [==============================] - 4s 2ms/step - loss: 0.7804 - accuracy: 0.7230 - val_loss: 0.6734 - val_accuracy: 0.7733
# Epoch 25/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7753 - accuracy: 0.7291 - val_loss: 0.6625 - val_accuracy: 0.7837
# Epoch 26/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7742 - accuracy: 0.7277 - val_loss: 0.6785 - val_accuracy: 0.7709
# Epoch 27/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7746 - accuracy: 0.7280 - val_loss: 0.6840 - val_accuracy: 0.7669
# Epoch 28/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.
100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7525 - accuracy: 0.7332 - val_loss: 0.6490 - val_accuracy: 0.7818
# Epoch 90/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7625 - accuracy: 0.7295 - val_loss: 0.6571 - val_accuracy: 0.7754
# Epoch 91/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7550 - accuracy: 0.7323 - val_loss: 0.6383 - val_accuracy: 0.7937
# Epoch 92/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7624 - accuracy: 0.7331 - val_loss: 0.6444 - val_accuracy: 0.7815
# Epoch 93/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7579 - accuracy: 0.7318 - val_loss: 0.6480 - val_accuracy: 0.7764
# Epoch 94/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7567 - accuracy: 0.7308 - val_loss: 0.6407 - val_accuracy: 0.7869
# Epoch 95/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7562 - accuracy: 0.7336 - val_loss: 0.6515 - val_accuracy: 0.7820
# Epoch 96/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7577 - accuracy: 0.7329 - val_loss: 0.6870 - val_accuracy: 0.7673
# Epoch 97/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7625 - accuracy: 0.7323 - val_loss: 0.6487 - val_accuracy: 0.7789
# Epoch 98/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7611 - accuracy: 0.7297 - val_loss: 0.6483 - val_accuracy: 0.7767
# Epoch 99/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7609 - accuracy: 0.7334 - val_loss: 0.6510 - val_accuracy: 0.7782
# Epoch 100/100
# 1427/1427 [==============================] - 4s 3ms/step - loss: 0.7572 - accuracy: 0.7318 - val_loss: 0.6618 - val_accuracy: 0.7770
# Training completed in +6.00 min.

# %%
results = complex_model.evaluate(X_test, y_test)
dict(zip(complex_model.metrics_names, results))
# Out:
# 535/535 [==============================] - 1s 2ms/step - loss: 0.6621 - accuracy: 0.7761
# {'loss': 0.6620977520942688, 'accuracy': 0.7761098146438599}

# %%
# Extract training and validation loss from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot the training and validation loss
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, c="blue", label='Training loss')
plt.plot(epochs, val_loss, c="red", label='Validation loss')
plt.title('(NN++) Training and Validation Loss\n(Multi-class Anomaly Detection)\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# y_pred has shape (9473, 4)
y_vect_pred = complex_model.predict(X_valid)

y_pred = np.argmax(y_vect_pred, axis=1)

# Create a confusion matrix
conf_matrix = confusion_matrix(y_valid, y_pred)

# Display a classification report
print("\n(more complex NN) Classification Report (Multi-class anomaly detection):\n")
print(classification_report(y_valid, y_pred))
# Out:
# (more complex NN) Classification Report (Multi-class anomaly detection):
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      5831
#            1       0.70      0.87      0.77      5718
#            2       0.74      0.67      0.70      5790
#            3       1.00      0.67      0.80      5487
#
#     accuracy                           0.78     22826
#    macro avg       0.80      0.78      0.78     22826
# weighted avg       0.80      0.78      0.78     22826

# %%
labaled_classes = ['normal','reorder', 'duplicate','corrupt']
classes = np.unique(y_train) 

classes = [classe+0.5 for classe in classes]

# Create a heatmap for the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.xticks(classes, labaled_classes, rotation=30)
plt.yticks(classes, labaled_classes, rotation=30)
plt.xlabel("<-------------------    Predicted Labels  ------------------->", fontsize=12, color="red", labelpad=18)
plt.ylabel("<-------------------    True Labels  ------------------->",  fontsize=12, color="red", labelpad=18)
plt.title("\n(more complex NN) Confusion Matrix (Multi-class Anomaly Detection)\n")
plt.tight_layout()
plt.show()

# %% [markdown]
# _**c. Discussion**_
#
# The problem of multi-class classification, and as we saw in the exploratory data analysis step, is not so complex. This explain the ability of sampler architecture to obtain mush better performance compared to the more complex one.
#
# Thus, we will pick the sampler variante as a representatif of neural network in our use case.
